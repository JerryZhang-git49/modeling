# %%
# 1. 数据基础库
# %pip install numpy pandas

# 2. 可视化库
# %pip install matplotlib seaborn

# 3. 机器学习库
# %pip install scikit-learn

# 4. 统计分析库
# %pip install statsmodels scipy
# Out:
# Requirement already satisfied: numpy in d:\modeling\.venv\lib\site-packages (2.2.6)
# Requirement already satisfied: pandas in d:\modeling\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: tzdata>=2022.7 in d:\modeling\.venv\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: pytz>=2020.1 in d:\modeling\.venv\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\modeling\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\modeling\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 26.1.2 is available.
# You should consider upgrading via the 'd:\modeling\.venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: matplotlib in d:\modeling\.venv\lib\site-packages (3.10.9)
# Requirement already satisfied: seaborn in d:\modeling\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\modeling\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in d:\modeling\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in d:\modeling\.venv\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\modeling\.venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\modeling\.venv\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in d:\modeling\.venv\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pyparsing>=3 in d:\modeling\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: numpy>=1.23 in d:\modeling\.venv\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: contourpy>=1.0.1 in d:\modeling\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pandas>=1.2 in d:\modeling\.venv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: tzdata>=2022.7 in d:\modeling\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: pytz>=2020.1 in d:\modeling\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in d:\modeling\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 26.1.2 is available.
# You should consider upgrading via the 'd:\modeling\.venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: scikit-learn in d:\modeling\.venv\lib\site-packages (1.7.2)
# Requirement already satisfied: joblib>=1.2.0 in d:\modeling\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: numpy>=1.22.0 in d:\modeling\.venv\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\modeling\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: scipy>=1.8.0 in d:\modeling\.venv\lib\site-packages (from scikit-learn) (1.15.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 26.1.2 is available.
# You should consider upgrading via the 'd:\modeling\.venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: statsmodels in d:\modeling\.venv\lib\site-packages (0.14.6)
# Requirement already satisfied: scipy in d:\modeling\.venv\lib\site-packages (1.15.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in d:\modeling\.venv\lib\site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in d:\modeling\.venv\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in d:\modeling\.venv\lib\site-packages (from statsmodels) (26.2)
# Requirement already satisfied: numpy<3,>=1.22.3 in d:\modeling\.venv\lib\site-packages (from statsmodels) (2.2.6)
# Requirement already satisfied: pytz>=2020.1 in d:\modeling\.venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\modeling\.venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\modeling\.venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\modeling\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 26.1.2 is available.
# You should consider upgrading via the 'd:\modeling\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder   #LabelEncoder （标签编码器）:将类别型文本数据转换为数值型整数
import matplotlib.pyplot as plt
import seaborn as sns

# 设置中文显示
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# 1.生成模拟天气数据

# %%
np.random.seed(42)
# 定义天气状态
weather_states = ['晴天', '阴天','雨天']
n_states = len(weather_states)

# 定义真实的转义概率矩阵
true_transition_matrix = np.array([
    [0.7,0.2,0.1],    # 晴天 -> [晴天, 阴天, 雨天]
    [0.3,0.4,0.3],    # 阴天 -> [晴天, 阴天, 雨天]
    [0.2,0.3,0.5]     # 雨天 -> [晴天, 阴天, 雨天]
])

# %% [markdown]
# 生成天气序列

# %%
def generate_weather_sequence(n_days, initial_state=0):
    #  initial_state=0  表示默认从"晴天"开始，因为  weather_states[0] = '晴天'
    """生成n天的天气序列"""
    sequence = [initial_state]  # 第一天天气已经确定
    current_state = initial_state

    for _ in range(n_days - 1):
        # 根据当前状态和转移概率选择下一个状态
        next_state = np.random.choice(
            n_states,  # 从 [0, 1, 2] 中选择
            p=true_transition_matrix[current_state]  # # 当前状态对应的转移概率
        )
        # 结果概率:(以第一次循环为例)
        #   → 0 (晴天)  概率 70%
        #   → 1 (阴天)  概率 20%  
        #   → 2 (雨天)  概率 10%
        # 则随机生成的数：落在[0,0.7)————晴天(0);落在[0.7,0.9)————阴天(1);落在[0.9,1]————雨天(2)
        sequence.append(next_state)
        current_state = next_state

    return sequence

# %%
# 生成30天的历史数据
historial_days = 30
weather_sequence = generate_weather_sequence(historial_days)
weather_names = [weather_states[i] for i in weather_sequence]

df = pd.DataFrame({
    '日期' : pd.date_range('2025-01-01', periods=historial_days),
    '天气状态' : weather_names,
    '状态编码' : weather_sequence
})

print("历史天气数据（前10天）：")
print(df.head(10))
print(f"\n数据形状：{df.shape}")
# Out:
# 历史天气数据（前10天）：
#           日期 天气状态  状态编码
# 0 2025-01-01   晴天     0
# 1 2025-01-02   晴天     0
# 2 2025-01-03   雨天     2
# 3 2025-01-04   雨天     2
# 4 2025-01-05   雨天     2
# 5 2025-01-06   晴天     0
# 6 2025-01-07   晴天     0
# 7 2025-01-08   晴天     0
# 8 2025-01-09   阴天     1
# 9 2025-01-10   阴天     1
#
# 数据形状：(30, 3)

# %% [markdown]
# 2.估计转移矩阵

# %%
def estimate_transition_matrix(sequence):
    """从观察序列估计转移概率矩阵"""
    n_states = len(set(sequence))  # 计算不同状态的数量 ——set(sequence)：去重，得到所有出现过的状态
    transition_counts = np.zeros((n_states, n_states))

    # 统计转移次数
    for i in range(len(sequence) - 1):
        current_state = sequence[i]
        next_state = sequence[i+1]
        transition_counts[current_state, next_state] += 1

    # 计算转移概率
    transition_matrix = np.zeros((n_states, n_states))
    for i in range(n_states):
        row_sum = transition_counts[i].sum()
        if row_sum > 0:
            transition_matrix[i] = transition_counts[i] / row_sum
        else:
            # 如果某个状态没有出现，使用均匀分布
            transition_matrix[i] = 1.0 / n_states

    return transition_matrix, transition_counts

# %% [markdown]
# 估计转移概率矩阵

# %%
estimated_matrix, counts_matrix = estimate_transition_matrix(weather_sequence)

print('\n转移次数矩阵')
counts_df = pd.DataFrame(
    counts_matrix,
    index = weather_states,
    columns = weather_states
)
print(counts_df) 

print('\n估计的转移概率矩阵')
prob_df = pd.DataFrame(
    estimated_matrix,
    index=weather_states,
    columns=weather_states
)
print(prob_df.round(3))
# Out:
# 转移次数矩阵
#       晴天   阴天   雨天
# 晴天  15.0  2.0  2.0
# 阴天   2.0  1.0  1.0
# 雨天   2.0  1.0  3.0
#
# 估计的转移概率矩阵
#        晴天     阴天     雨天
# 晴天  0.789  0.105  0.105
# 阴天  0.500  0.250  0.250
# 雨天  0.333  0.167  0.500

# %% [markdown]
# 可视化转移概率矩阵

# %%
plt.figure(figsize=(10,8))

# 子图1：热力图
plt.subplot(2,2,1)
sns.heatmap(estimated_matrix, annot=True, fmt='.3f', 
            xticklabels=weather_states, yticklabels=weather_states,
            cmap='Blues', cbar_kws={'label':'转移概率'})
plt.title('估计的转移概率矩阵')


# 子图2：状态转移图
plt.subplot(2,2,2)
G = np.zeros((n_states, n_states))
for i in range(n_states):
    for j in range(n_states):
        if estimated_matrix[i,j] > 0.1:
            #只保留概率大于0.1的转移数据
            G[i,j] = estimated_matrix[i,j]

pos = {0:(0,1), 1:(1,1), 2:(0.5,0)}  #三个节点位置
for i in range(n_states):
    plt.scatter(pos[i][0], pos[i][1], s=1000, c='lightblue', edgecolors='black', linewidths=2)
    # plt.text显示文本————ha='center', va='center'分别代表水平对齐和垂直对齐
    plt.text(pos[i][0], pos[i][1], weather_states[i], ha='center', va='center', fontsize=12)

# 绘制箭头
for i in range(n_states):
    for j in range(n_states):
        if G[i,j] > 0:
            if i != j:
                #plt.annotate画箭头————''表示无文本，xy代表终点，xytext代表起点，arrowprps代表样式
                plt.annotate('', xy=pos[j], xytext=pos[i], 
                             arrowprops=dict(arrowstyle='->', lw=2, color='gray', alpha=0.7))
                # 添加概率标签
                mid_x = (pos[i][0] + pos[j][0]) / 2
                mid_y = (pos[i][1] + pos[j][1]) / 2
                #  bbox:文本框设置
                plt.text(mid_x, mid_y, f'{G[i,j]:.2f}', ha='center', va='center',fontsize=10,
                         bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=0.8))

# 设置xy轴范围，使图形不贴边
plt.xlim(-0.5,1.5)
plt.ylim(-0.5,1.5)
# 隐藏坐标轴
plt.axis('off')
plt.title('状态转移图')
# Out:
# Text(0.5, 1.0, '状态转移图')

# %% [markdown]
# 天气预测

# %%
def predict_weather(current_state, transition_matrix, n_days):
    """预测未来n天的天气"""
    predictions = []
    state_probs = []

    # 初始状态概率向量
    current_prob = np.zeros(len(weather_states))
    current_prob[current_state] = 1.0

    for day in range(n_days):
        # 计算下一天的状态概率
        current_prob = current_prob @ transition_matrix
        state_probs.append(current_prob.copy())  #current_prob 是数组对象，每次循环会修改它。不用 copy() 会导致列表中所有元素指向同一个最终值

        # 选择最可能的状态作为预测
        predicted_state = np.argmax(current_prob)   # argmax返回最大值的索引
        predictions.append(predicted_state)

    return predictions, state_probs

# %% [markdown]
# 预测未来7天的天气

# %%
current_weather = weather_sequence[-1]  # 使用最后一天的状态
forecast_days = 7
predictions, probabilities = predict_weather(current_weather, estimated_matrix, forecast_days)

# 创建预测结果数据集
forecast_df = pd.DataFrame({
    #  pd.Timedelta(days=1) 表示"1天"的时间差     pd.date_range(df['日期'].iloc[-1] + pd.Timedelta(days=1)表示预测的起始日期
    '预测日期' : pd.date_range(df['日期'].iloc[-1] + pd.Timedelta(days=1), periods=forecast_days),
    '预测天气' : [weather_states[i] for i in predictions],
    '晴天概率': [p[0] for p in probabilities],
    '阴天概率': [p[1] for p in probabilities],
    '雨天概率': [p[2] for p in probabilities]
})

print("\n未来7天天气预测:")
print(forecast_df.round(3))
# Out:
# 未来7天天气预测:
#         预测日期 预测天气   晴天概率   阴天概率   雨天概率
# 0 2025-01-31   晴天  0.789  0.105  0.105
# 1 2025-02-01   晴天  0.711  0.127  0.162
# 2 2025-02-02   晴天  0.679  0.134  0.188
# 3 2025-02-03   晴天  0.665  0.136  0.199
# 4 2025-02-04   晴天  0.659  0.137  0.203
# 5 2025-02-05   晴天  0.657  0.138  0.205
# 6 2025-02-06   晴天  0.656  0.138  0.206

# %%
# 子图3：预测概率变化
plt.subplot(2,2,3)
days = range(1,forecast_days+1)
for i, state in enumerate(weather_states):
    probs = [p[i] for p in probabilities]
    plt.plot(days, probs, marker='o', label=state, linewidth=2)

plt.xlabel('预测天数')
plt.ylabel('概率')
plt.title('未来天气状态概率变化')
plt.legend()
plt.grid(True, alpha=0.3)

# %% [markdown]
# 计算稳态分布

# %%
def compute_steady_state(transition_matrix):
    """计算马尔可夫链的稳态分布"""
    # 求解 π = π * P
    # 等价于求解 (P^T - I)π = 0, 且 sum(π) = 1
    n = transition_matrix.shape[0]
    A = transition_matrix.T - np.eye(n)  # 表示P^T - I
    A = np.vstack([A,np.ones(n)])  # 在最后一行加一行1————添加约束条件 Σπ_i = 1
    b = np.zeros(n+1)
    b[-1] = 1  # 在最后一行加一行1————添加约束条件 Σπ_i = 1

    # 使用最小二乘法
    steady_state = np.linalg.lstsq(A,b,rcond=None)[0]
    return steady_state

steady_state = compute_steady_state(estimated_matrix)

print('\n稳态分布')
for i, state in enumerate(weather_states):
    print(f'{state} : {steady_state[i]:.3f}')
# Out:
# 稳态分布
# 晴天 : 0.655
# 阴天 : 0.138
# 雨天 : 0.207

# %%
# 子图4：长期预测vs稳态
plt.subplot(2,2,4)

long_term_days = 30
_, lomg_term_probs = predict_weather(current_weather, estimated_matrix, long_term_days)

for i, state in enumerate(weather_states):
    probs = [p[i] for p in lomg_term_probs]
    plt.plot(range(1,long_term_days+1), probs, label=f'{state}')
    plt.axhline(y=steady_state[i], color='grey', linestyle='--', alpha=0.5)

plt.xlabel('预测天数')
plt.ylabel('概率')
plt.title('长期预测收敛到稳态分布')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# 6.模型评估

# %%
def evaluate_markov_property(sequence):
    """检验序列的马尔可夫性"""
    # 简单的卡方检验————核心假设：P(X_t+1 | X_t) = P(X_t+1 | X_t, X_t-1)
    n = len(sequence)

    # 统计一阶转移
    first_order_counts = np.zeros((n_states, n_states))
    for i in range(n-1):
        first_order_counts[sequence[i],sequence[i+1]] += 1

    # 统计二阶转移
    second_order_counts = {}
    for i in range(n - 2):
        key = (sequence[i], sequence[i+1])
        next_state = sequence[i+2]
        if key not in second_order_counts:
            second_order_counts[key] = np.zeros(n_states)
        second_order_counts[key][next_state] += 1
    
    print("\n马尔可夫性检验：")
    print("如果满足马尔可夫性，P(X_t+1|X_t) 应该与 P(X_t+1|X_t,X_t-1) 相似")
    
    # 比较一阶和二阶转移概率
    for (prev_prev, prev), counts in second_order_counts.items():
        if counts.sum() > 5:  # 只考虑有足够观察的情况
            second_order_prob = counts / counts.sum()
            first_order_prob = estimated_matrix[prev]
            diff = np.abs(second_order_prob - first_order_prob).mean()
            print(f"\n从 ({weather_states[prev_prev]},{weather_states[prev]}) 出发:")
            print(f"  二阶转移概率: {second_order_prob.round(3)}")
            print(f"  一阶转移概率: {first_order_prob.round(3)}")
            print(f"  平均差异: {diff:.3f}")

evaluate_markov_property(weather_sequence)
# Out:
# 马尔可夫性检验：
# 如果满足马尔可夫性，P(X_t+1|X_t) 应该与 P(X_t+1|X_t,X_t-1) 相似
#
# 从 (晴天,晴天) 出发:
#   二阶转移概率: [0.786 0.143 0.071]
#   一阶转移概率: [0.789 0.105 0.105]
#   平均差异: 0.025
